# %%
import spotipy
import pandas as pd
import config
from spotipy.oauth2 import SpotifyClientCredentials

# %%
def get_artist_data(artist):
    results = sp.search(q='artist:' + artist, type='artist',limit=1)
    try:
        #Retrieve artist follower and popularity info
        genre1 = results.get('artists').get('items')[0].get('genres')[0]
        genre2 = results.get('artists').get('items')[0].get('genres')[1]
    except IndexError:
        #Return NaN if no info is found for an artist
        genre1 = 'NaN'
        genre2 = 'NaN'
    return genre1, genre2

# %%
artist_df = pd.read_csv('Data/artist_df.csv',index_col=0)

# %%
artist_df.head()
# Out:
#                            artist  spotify_followers  spotify_popularity
# 0  Mannheim Steamroller Christmas                NaN                 NaN
# 1                   Joe Bonamassa           298790.0                64.0
# 2                Jennifer Nettles            83152.0                54.0
# 3                       Home Free            84183.0                62.0
# 4                            Styx           307254.0                65.0

# %%
#Input login credentials
client_credentials_manager = SpotifyClientCredentials(client_id=config.spotify_key,client_secret=config.spotify_secret)
#Initiate Spotify connection object
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#Retrieve follower and popularity info for each artist
artist_df['spotify_genre1'],artist_df['spotify_genre2']= zip(*artist_df['artist'].apply(get_artist_data))
#How many artists we coulnd't find info for
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b63017224ba7> in <module>()
#       6 artist_df['spotify_genre1'],artist_df['spotify_genre2']= zip(*artist_df['artist'].apply(get_artist_data))
#       7 #How many artists we coulnd't find info for
# ----> 8 artist_df.loc[artist_df['spotify_followers'] =='NaN'].count()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
# ...

# %%
artist_df
# Out:
#                               artist  spotify_followers  spotify_popularity  \
# 0     Mannheim Steamroller Christmas                NaN                 NaN
# 1                      Joe Bonamassa           298790.0                64.0
# 2                   Jennifer Nettles            83152.0                54.0
# 3                          Home Free            84183.0                62.0
# 4                               Styx           307254.0                65.0
# 5              Black Jacket Symphony                NaN                 NaN
# 6                       Sister Hazel            79125.0                58.0
# 7                       Taylor Hicks             3294.0                30.0
# 9        Jason Isbell & the 400 Unit            32394.0                63.0
# 10                    James McMurtry            22247.0                49.0
# 16                            Xscape           331305.0                61.0
# ...
